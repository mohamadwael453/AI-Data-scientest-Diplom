# %%
if True :
  print("allows will print ")
# Out:
# allows will print

# %%
if False :
  print ("this will not print ")

# %%
if 10 ==10 :
  print("this is true")
# Out:
# this is true

# %%
if 10==11 :
  print("this is false ")

# %%
score = 0
if score >= 50 :
  print ("pass")
else:
  print("fail")
# Out:
# pass

# %%
score = float(input("plaase enter your score : "))
if score>=50 :
  print("pass")
elif score <50 and score >=0 :
    print ("faild")
else :
  print ("invalid score")
# Out:
# plaase enter your score : -33
# invalid score

# %% [markdown]
# Lab 1

# %%
username=input("what is your user name :")
age=int (input("your age is :"))
if age >= 18 and username=='admin':
  print("welcom boss, nice to see you again")
elif age>=18 and not username=='admin':
   print("welcom user")
else :
  print("you are too young to enter")
# Out:
# what is your user name :admin
# your age is :20
# welcom boss, nice to see you again

# %% [markdown]
# Lab 2

# %%
n=int (input("enter your number : "))
if n%2==0 and n%3==0 :
  print ("divisible by both")
elif n%2==0 and n%3!=0 :
 print ("divisible by 2 only")
elif n%2!=0 and n%3==0 :
 print ("divisible by 3 only")
else :
 print ("not divisible by 2 or 3 ")
# Out:
# enter your number : 7
# not divisible by 2 or 3
