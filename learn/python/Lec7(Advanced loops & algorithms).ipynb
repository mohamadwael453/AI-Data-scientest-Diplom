# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamadwael453/AI-Data-scientest-Diplom/blob/main/learn/python/Lec7(Advanced%20loops%20%26%20algorithms).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test code

# %%
l=[1,2,3,4,5,6,7]
for i in l :
  if   i==5 :
    print("found 5 ! stop the loop ")
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4
# found 5 ! stop the loop

# %%
arr=[3,7,9,10,15]
for i in arr :
  if i==10 :
    continue
  print(i)
# Out:
# 3
# 7
# 9
# 15

# %%
i =0
while i<= 10 :
  if i%2 == 0:
    print ("even number : ", i)
  else :
    print (" odd number : ", i)
  i+=1
  print ("")
# Out:
# even number :  0
#
#  odd number :  1
#
# even number :  2
#
#  odd number :  3
#
# even number :  4
#
#  odd number :  5
#
# even number :  6
#
#  odd number :  7
#
# even number :  8
#
#  odd number :  9
#
# even number :  10

# %%
num = int(input("enter the number: "))
counter = 0

while num > 0:
    num = num // 10
    counter += 1

print(f"The number of digits is: {counter}")
# Out:
# enter the number: 1593
# The number of digits is: 4

# %% [markdown]
# # Laps

# %%
name="admin"
password = 1234

while True:
    user_name = input("enter the user name : ")
    user_password = int(input("enter the user name : "))
    if user_name == name and user_password ==password :
        print("success")
        break
    else:
        print("invalid user name or password")
# Out:
# enter the user name : admin
# enter the user name : 1234
# success

# %%
i=0
while i <=calc :
  calc= int(input ("please enter the number of operation: "))
  if calc==5 :
     break
  x=int(input("please enter the first number : "))
  y=int(input("please enter the second number : "))
  if calc == 1:
    print( "the sum of two number is : " ,x+y)
  elif calc == 2:
    print( "the difference of two number is : " ,x-y)
  elif calc == 3:
    print( "the product of two number is : " ,x*y)
  elif calc == 4:
    print( "the division of two number is : " ,x/y)
  else :
    print("invalid operation")
# Out:
# please enter the number of operation: 1
# please enter the first number : 20
# please enter the second number : 30
# the sum of two number is :  50
# please enter the number of operation: 1
# please enter the first number : 60
# please enter the second number : 90
# the sum of two number is :  150
