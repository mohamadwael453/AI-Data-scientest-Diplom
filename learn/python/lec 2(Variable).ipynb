# %%
numone=20
numtwo =25
print(numone+numtwo)
# Out:
# 45

# %%
price=float(input("price = "))
total = price+(14/100)*price
print("total cost after the taxes : ", total,"$")
# Out:
# price = 220.32
# total cost after the taxes :  251.16479999999999 $

# %% [markdown]
# Lab 1

# %%
grad1=float(input("Please enter the first grade :"))
grad2=float(input("Please enter the second grade :"))
grad3=float(input("Please enter the third grade :"))
avrage = (grad1+grad2+grad3)/3
print("avrage for three gradies is : ", avrage )
# Out:
# Please enter the first grade :100
# Please enter the second grade :30
# Please enter the third grade :80
# avrage for three gradies is :  70.0
