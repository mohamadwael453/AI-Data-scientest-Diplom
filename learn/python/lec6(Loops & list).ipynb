# %% [markdown]
# # Try

# %%
L=[1 , 2 , 4 , 6 , 8 ,10 ]
for i in L :
  print(i)
# Out:
# 1
# 2
# 4
# 6
# 8
# 10

# %%
print ( 5 in L)
print (8 in L)
# Out:
# False
# True

# %%
n = int (input())
for i in range (1,n,3):
  print (i)

# %%
x=["ab","cd"]
index = 0
for i in x :
  x [index]=i.upper()
  index +=1

print(x)

# %%
y=list (input("eneter the numbers "))
large = -1000
for i in y :
  if i>large:
   large =i
print(large)

# %%
for i in range(3):
  for j in range(4):
    print ("*", end=" ")
  print ()
# Out:
# * * * *
# * * * *
# * * * *

# %%
print("*", end=" ")
print("*")
# Out:
# * *

# %%
matrix =[[1,2,3],[4,5,6],[7,8,9]]
total =0
for row in matrix:
  for num in row:
    total +=num
  print("row = ",total)
print("total = ",total)
# Out:
# row =  6
# row =  21
# row =  45
# total =  45

# %%
arr=[]
for i in range(3):
  x=int(input())
  arr.append(x)
print(arr)
# Out:
# 10
# 2
# 3
# [10, 2, 3]

# %%
arr=[]
num =int(input("enter the number "))
for i in range(num):
  x=int(input())
  arr.append(x)
print(arr)
# Out:
# enter the number 10
# 2
# 3
# 6
# 9
# 10
# 16
# 78
# 96
# 106
# 189
# [2, 3, 6, 9, 10, 16, 78, 96, 106, 189]

# %%
x=input("enter something")
print(x)
print(type(x))
l=list(map(int,x.split()))
print(l)
print(type(l))
# Out:
# enter something10  2 5
# 10  2 5
# <class 'str'>
# [10, 2, 5]
# <class 'list'>

# %%
L=[1,80 ,9 ,'A']
for i in L:
  print(i,end=" ")
print("")
for index in range(len(L)):
  print(index,end=" ")
# Out:
# 1 80 9 A
# 0 1 2 3

# %% [markdown]
# # Labs

# %%
for i in range(1,6):
  for j in range(i):
    print("*",end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
entergrad= input("enter the grade:")
match entergrad:
  case "A":
    print("excellent")
  case "B":
    print("VERY GOOD")
  case "C":
    print("GOOD")
  case "D":
    print("PASS")
  case "F":
    print("FAIL")
  case _:
    print("INVALLED")
# Out:
# enter the grade:A
# excellent
